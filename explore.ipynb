# %%
import nltk 
from nltk.corpus import cmudict
import string
import numpy as np
import pandas as pd
from pprint import pprint

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Explore sonnets

# %%
sonnet_df = pd.read_csv('./full_sonnet_df.csv')

sonnet_df.columns = ['unnamed', 'unnamed1', 'sonnet_index', 'syllables', 's1', 's2', 's3',
       's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12',
       'word_list', 'sonnet_num', 'author', 'polarity', 'subjectivity', 'sonnet']

# unnecessary columns

sonnet_df = sonnet_df.drop('unnamed', axis=1)
sonnet_df = sonnet_df.drop('unnamed1', axis=1)

sonnet_df.head(2)
# Out:
#    sonnet_index  syllables        s1      s2        s3      s4        s5  \
# 0             2         10  unstress  stress  unstress  stress  unstress
# 1             3         11  unstress  stress    stress  stress  unstress
#
#        s6        s7      s8        s9     s10      s11      s12  \
# 0  stress  unstress  stress  unstress  stress  missing  missing
# 1  stress    stress  stress  unstress  stress  missing  missing
#
#                                            word_list  sonnet_num       author  \
# 0  ['From', 'fairest', 'creatures', 'we', 'desire...           1  Shakespeare
# 1  ['That', 'thereby', 'beauty', 'rose', 'might',...           1  Shakespeare
#
#    polarity  subjectivity  sonnet
# 0       0.0          0.00       1
# 1       0.6          0.95       1

# %%
sonnet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5119 entries, 0 to 5118
# Data columns (total 20 columns):
# sonnet_index    5119 non-null int64
# syllables       5119 non-null int64
# s1              5119 non-null object
# s2              5119 non-null object
# s3              5119 non-null object
# s4              5119 non-null object
# s5              5119 non-null object
# s6              5119 non-null object
# s7              5119 non-null object
# s8              5119 non-null object
# s9              5119 non-null object
# s10             5119 non-null object
# s11             5119 non-null object
# s12             5119 non-null object
# word_list       5119 non-null object
# sonnet_num      5119 non-null int64
# author          5035 non-null object
# polarity        5119 non-null float64
# subjectivity    5119 non-null float64
# sonnet          5119 non-null int64
# dtypes: float64(2), int64(4), object(14)
# memory usage: 799.9+ KB

# %%
sonnet_df.s1.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s2.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s3.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s4.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s5.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s6.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s7.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s8.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s9.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s10.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s11.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df.s12.value_counts().plot(kind='bar')
plt.show()

# %%
sonnet_df['syllables'].value_counts()
# Out:
# 10    3211
# 11     896
# 9      699
# 12     144
# 8      105
# 6       23
# 7       18
# 13       8
# 5        5
# 4        5
# 3        3
# 2        2
# Name: syllables, dtype: int64

# %%
sns.distplot(sonnet_df['polarity'], bins=10, kde=False, rug=True)

# %%
sns.distplot(sonnet_df['subjectivity'], bins=10, kde=False, rug=True)

# %% [markdown]
# # Explore text

# %%
text_df = pd.read_csv('./full_text_df.csv')

text_df.columns = ['unnamed', 'unnamed1', 'sonnet_index', 'syllables', 's1', 's2', 's3',
       's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12',
       'word_list', 'sonnet_num', 'author', 'polarity', 'subjectivity', 'sonnet']

# unnecessary columns

text_df = text_df.drop('unnamed', axis=1)
text_df = text_df.drop('unnamed1', axis=1)

text_df.head(2)
# Out:
#    sonnet_index  syllables        s1        s2        s3      s4        s5  \
# 0             0          9    stress    stress    stress  stress  unstress
# 1             1          9  unstress  unstress  unstress  stress  unstress
#
#          s6      s7        s8        s9      s10      s11      s12  \
# 0  unstress  stress  unstress  unstress  missing  missing  missing
# 1  unstress  stress  unstress  unstress  missing  missing  missing
#
#                                    word_list  sonnet_num  author  polarity  \
# 0  ['It', 'is', 'a', 'truth', 'universally']           0  Austen       0.0
# 1  ['It', 'is', 'a', 'truth', 'universally']           1  Austen       0.0
#
#    subjectivity  sonnet
# 0           0.0       0
# 1           0.0       0

# %%
text_df.s1.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s2.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s3.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s4.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s5.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s6.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s7.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s8.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s9.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s10.value_counts().plot(kind='bar')
plt.show()

# %%
text_df.s11.value_counts().plot(kind='bar')
plt.show()

# %%
text_df['syllables'].value_counts()
# Out:
# 11    3223
# 10    2208
# 9     1227
# 8      641
# 7      240
# 6      108
# 5       16
# 4        6
# Name: syllables, dtype: int64

# %%
sns.distplot(text_df['syllables'], bins=10, kde=False, rug=True)

# %%
sns.distplot(text_df['polarity'], bins=10, kde=False, rug=True)

# %%
sns.distplot(text_df['subjectivity'], bins=10, kde=False, rug=True)
